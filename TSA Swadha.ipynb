# %% [markdown]
# **IMPORTING REQUIRED LIBRARIES**

# %%
import numpy as np
import pandas as pd
import re
import nltk

# %% [markdown]
# **LOADING THE DATASET**

# %%
t_data = pd.read_csv("/content/drive/MyDrive/ML INTERNSHIPS/dataset.csv", encoding='ISO-8859-1')
# Encoding was kept ISO-8859-1 so as to remove the errors of utf-8 encoding

# %%
t_data.head(10)
# Out:
#    ItemID  Sentiment                                      SentimentText
# 0       1          0                       is so sad for my APL frie...
# 1       2          0                     I missed the New Moon trail...
# 2       3          1                            omg its already 7:30 :O
# 3       4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4       5          0           i think mi bf is cheating on me!!!   ...
# 5       6          0                  or i just worry too much?
# 6       7          1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7       8          0         Sunny Again        Work Tomorrow  :-|  ...
# 8       9          1        handed in my uniform today . i miss you ...
# 9      10          1           hmmmm.... i wonder how she my number @-)

# %% [markdown]
# **VISUALISING RANDOM TWEETS IN THE DATASET**

# %%
random_i = np.random.randint(1,len(t_data),40).tolist()
t_data["SentimentText"][random_i]
# Out:
# 95435       @CrayolaDeUva whisky gratissssssssssss wooooo
# 52235    @ashutosh383  I mean if the so called hunk has...
# 80588    @Cari_tx http://twitpic.com/6pv6x - yummy... c...
# 20856                                  @__Tricia__ thanks
# 23735    @abbydelmundo sounds like you had a rough nigh...
# 27768    @AhmNoHere oh, poppet!  Where in Her majesty's...
# 37330    @alisonmyra It's called a RipStick.  When I ha...
# 47049    @april_miss how come you didnt get to enjoy yo...
# 94672    @courtneycompton nononooooo. like the clothing...
# 87541    @charm_maker raffle is tomorrow morning. Thank...
# 6605                     #movieawards Momento WTF owna!!!
# 3041                     no B-ball 2day Gyms getting fixed
# 26625                          @Adrienne_Bailon of course
# 75792    @AnthonyM_ lol sweet. but the pen left me with...
# 43442                 @alexwithuptop they r hurting still
# 577       &quot;I'm a freelance writer for Braille porn...
# 59761                          @bevhilllslove YEY!!!!!!!!
# 39898    @Andre_R its been my mission to find other sou...
# 87551                             @charmarie night girly!
# 51067    @AsylumPhoto Just re-read your tweet. Yes, I'm...
# 6095      remembered something while reading. &quot;shu...
# 88960    @cjayphillips that is the saddest thing i've e...
# 6213     #Iranelection Obama &quot;Deeply Troubled&quot...
# 69255    @bradhawkins87 oh... i've never heard u call m...
# 11755                           #vimeo loads slowly today
# 79947                   @can't wait to see you guys live.
# 80302    @artate  yes, they've alot to learn from 1 ano...
# 68147    @AmyMommaerts I like that quote because it mak...
# 74764                   @annonymouss no im confuzzled 101
# 45892          @antoniamoreno Really really miss you too
# 69638    @AnditisLiz let me know how the expresso works...
# 37908    @amazingphoebe tomorrowwww, im doing nothing, ...
# 56087             @badnewsbeerz I'll be there coach!!!!!!
# 59779    @bevysmith. Hola Bevy ! I'm very legal  http:/...
# 78024    @cbeard agreed! I had the same prob on a plane...
# 40497    @ameh Miss Einea Henderson lool she's a charac...
# 78427    @CDAWGLINLEY http://bit.ly/SFOyH  who are thes...
# 57553                          @bbitzy: Are you working??
# 89144    @B2design Bread and butter does always hit the...
# 61246    @Bigsho222 no need to worry about that. i know...
# Name: SentimentText, dtype: object

# %% [markdown]
# **EXPLORING EMOTICONS IN OUR DATASET**

# %%
tweet_sen = t_data.SentimentText.str.cat()
emo = set(re.findall(r" ([-'@#\/]?.[$xX:;]) ",tweet_sen))
emo_cnt = []
for e in emo:
    emo_cnt.append((tweet_sen.count(e), e))

# %%
emo_cnt
# Out:
# [(33, 'C:'),
#  (115, 't:'),
#  (5, 'Rx'),
#  (7, 'A:'),
#  (55, '$$'),
#  (5, 'Dx'),
#  (8, 'D;'),
#  (32, 'c:'),
#  (5, '/:'),
#  (95, 'D:'),
#  (2, 'Q:'),
#  (73, '.:'),
#  (14, 'Ox'),
#  (3, '8;'),
#  (1120, ' ;'),
#  (25, '.x'),
#  (10, 'wx'),
#  (5, 'Fx'),
#  (245, '::'),
#  (33, '0:'),
#  (3, '*$'),
#  (1219, 'ox'),
#  (264, 'Ex'),
#  (18, 'S:'),
#  (22, 'FX'),
#  (15, '.;'),
#  (38, '3x'),
#  (1, '#2:'),
#  (42, 'AX'),
#  (46, 'OX'),
#  (12, 'Tx'),
#  (12, ':x'),
#  (23, 'xX'),
#  (59, 'Xx'),
#  (73, '1:'),
#  (1, '#UX'),
#  (17, '4x'),
#  (148, 'tx'),
#  (7, 'B:'),
#  (46, '4:'),
#  (6, 'G:'),
#  (16, '5x'),
#  (6, '(;'),
#  (2, 'C$'),
#  (2, '];'),
#  (1214, 'xx'),
#  (57, '2:'),
#  (37, '9:'),
#  (237, 'ux'),
#  (5, 'P:'),
#  (65, 'XX'),
#  (1979, ' :'),
#  (7178, 'ex'),
#  (5, 'RX'),
#  (6, 'O:'),
#  (32, 'x:'),
#  (24, '2x'),
#  (2, '@$$'),
#  (61, '):'),
#  (125, '(:'),
#  (5, ':X'),
#  (461, ' X'),
#  (6, 'Yx'),
#  (4, '(x'),
#  (6, ':$'),
#  (4, 'M$'),
#  (52, '3:'),
#  (31, 'TX'),
#  (2, ':;'),
#  (3, '@:'),
#  (19, 'DX'),
#  (9, '9x'),
#  (44, ';;'),
#  (2128, ' x')]

# %%
sorted(emo_cnt)
# Out:
# [(1, '#2:'),
#  (1, '#UX'),
#  (2, ':;'),
#  (2, '@$$'),
#  (2, 'C$'),
#  (2, 'Q:'),
#  (2, '];'),
#  (3, '*$'),
#  (3, '8;'),
#  (3, '@:'),
#  (4, '(x'),
#  (4, 'M$'),
#  (5, '/:'),
#  (5, ':X'),
#  (5, 'Dx'),
#  (5, 'Fx'),
#  (5, 'P:'),
#  (5, 'RX'),
#  (5, 'Rx'),
#  (6, '(;'),
#  (6, ':$'),
#  (6, 'G:'),
#  (6, 'O:'),
#  (6, 'Yx'),
#  (7, 'A:'),
#  (7, 'B:'),
#  (8, 'D;'),
#  (9, '9x'),
#  (10, 'wx'),
#  (12, ':x'),
#  (12, 'Tx'),
#  (14, 'Ox'),
#  (15, '.;'),
#  (16, '5x'),
#  (17, '4x'),
#  (18, 'S:'),
#  (19, 'DX'),
#  (22, 'FX'),
#  (23, 'xX'),
#  (24, '2x'),
#  (25, '.x'),
#  (31, 'TX'),
#  (32, 'c:'),
#  (32, 'x:'),
#  (33, '0:'),
#  (33, 'C:'),
#  (37, '9:'),
#  (38, '3x'),
#  (42, 'AX'),
#  (44, ';;'),
#  (46, '4:'),
#  (46, 'OX'),
#  (52, '3:'),
#  (55, '$$'),
#  (57, '2:'),
#  (59, 'Xx'),
#  (61, '):'),
#  (65, 'XX'),
#  (73, '.:'),
#  (73, '1:'),
#  (95, 'D:'),
#  (115, 't:'),
#  (125, '(:'),
#  (148, 'tx'),
#  (237, 'ux'),
#  (245, '::'),
#  (264, 'Ex'),
#  (461, ' X'),
#  (1120, ' ;'),
#  (1214, 'xx'),
#  (1219, 'ox'),
#  (1979, ' :'),
#  (2128, ' x'),
#  (7178, 'ex')]

# %%
HAPPY_EMO = r" ([xX;:]-?[dD)]|:-?[\)]|[;:][pP]) "
SAD_EMO = r" (:'?[/|\(]) "
print("Happy emoticons:", set(re.findall(HAPPY_EMO, tweet_sen)))
print("Sad emoticons:", set(re.findall(SAD_EMO, tweet_sen)))
# Out:
# Happy emoticons: {':p', 'xD', ':D', ';-D', 'XD', ':-D', 'xd', ';)', ';p', 'x)', ';d', ';D', ';P', ';-)', ':d'}
# Sad emoticons: {':|', ':(', ":'(", ':/'}

# %% [markdown]
# **EXPLORING WORDS IN OUR DATASET**

# %%
#Downloading punkt sentence tokenizer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Tokenizing
from nltk.tokenize import word_tokenize

def max_count_words(text):
    token = word_tokenize(text)
    freq_d = nltk.FreqDist(token)
    print("%d different words" % len(set(token)))
    return sorted(freq_d,key=freq_d.__getitem__, reverse=True)

# %%
max_count_words(t_data.SentimentText.str.cat())[:100]
# Out:
# 134028 different words
# ['@',
#  '!',
#  '.',
#  'I',
#  ',',
#  'to',
#  'the',
#  'you',
#  '?',
#  'a',
#  'it',
#  'i',
#  '...',
#  ';',
#  'and',
#  '&',
#  'my',
#  'for',
#  'is',
#  'that',
#  "'s",
#  "n't",
#  'in',
#  'of',
#  'me',
#  'have',
#  'on',
#  'quot',
#  "'m",
#  'so',
#  ':',
#  'but',
#  '#',
#  'do',
#  'was',
#  'be',
#  'not',
#  'your',
#  'are',
#  'just',
#  'with',
#  'like',
#  '-',
#  'at',
#  'too',
#  'get',
#  'good',
#  'u',
#  'up',
#  'know',
#  'all',
#  'this',
#  'now',
#  'no',
#  'we',
#  'out',
#  ')',
#  'love',
#  'can',
#  '(',
#  'what',
#  'one',
#  'will',
#  'lol',
#  'go',
#  'about',
#  'did',
#  "'ll",
#  'got',
#  'amp',
#  'there',
#  'day',
#  'http',
#  'see',
#  "'re",
#  'if',
#  'time',
#  'they',
#  'think',
#  'as',
#  'when',
#  'from',
#  'You',
#  'It',
#  'going',
#  'really',
#  'am',
#  'work',
#  'well',
#  'had',
#  'would',
#  'how',
#  'he',
#  'here',
#  'some',
#  'thanks',
#  'back',
#  'im',
#  'haha',
#  'or']

# %%
#Downloading stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Stopwords
from nltk.corpus import stopwords

mwords = max_count_words(t_data.SentimentText.str.cat())
max_words = []
for w in mwords:
    if len(max_words) == 1000:
        break
    if w in stopwords.words("english"):
        continue
    else:
        max_words.append(w)
# Out:
# 134028 different words

# %%
max_words
# Out:
# ['@',
#  '!',
#  '.',
#  'I',
#  ',',
#  '?',
#  '...',
#  ';',
#  '&',
#  "'s",
#  "n't",
#  'quot',
#  "'m",
#  ':',
#  '#',
#  'like',
#  '-',
#  'get',
#  'good',
#  'u',
#  'know',
#  ')',
#  'love',
#  '(',
#  'one',
#  'lol',
#  'go',
#  "'ll",
#  'got',
#  'amp',
#  'day',
#  'http',
#  'see',
#  "'re",
#  'time',
#  'think',
#  'You',
#  'It',
#  'going',
#  'really',
#  'work',
#  'well',
#  'would',
#  'thanks',
#  'back',
#  'im',
#  'haha',
#  'want',
#  'ca',
#  'na',
#  'much',
#  'still',
#  'today',
#  "'ve",
#  '2',
#  'need',
#  'hope',
#  'miss',
#  'sorry',
#  'great',
#  'could',
#  'right',
#  'Thanks',
#  'though',
#  'oh',
#  'new',
#  'make',
#  'fun',
#  'yeah',
#  'last',
#  'night',
#  'better',
#  '3',
#  'come',
#  'lt',
#  'feel',
#  'That',
#  "'",
#  'The',
#  'sad',
#  'bad',
#  'way',
#  'wish',
#  'LOL',
#  'home',
#  'But',
#  'nice',
#  'ur',
#  'say',
#  'sure',
#  '..',
#  'never',
#  'And',
#  'even',
#  'Oh',
#  'wait',
#  'dont',
#  'yes',
#  'people',
#  'always',
#  'soon',
#  "'d",
#  'week',
#  'twitter',
#  'gon',
#  'We',
#  'tomorrow',
#  'My',
#  'awesome',
#  'morning',
#  'next',
#  'take',
#  'us',
#  'thing',
#  'No',
#  'show',
#  'guys',
#  'happy',
#  'cool',
#  '--',
#  'hear',
#  'something',
#  'Good',
#  'hey',
#  'look',
#  'tonight',
#  'getting',
#  'let',
#  'find',
#  'thank',
#  'yet',
#  'ya',
#  'ok',
#  '4',
#  'little',
#  'wan',
#  'Just',
#  'thought',
#  'How',
#  'x',
#  'already',
#  'follow',
#  'So',
#  'hate',
#  'long',
#  'What',
#  'cant',
#  'sleep',
#  'days',
#  'pretty',
#  'watch',
#  'Have',
#  'tell',
#  'best',
#  'said',
#  'man',
#  'thats',
#  'first',
#  'help',
#  'try',
#  'weekend',
#  'made',
#  'please',
#  'things',
#  'Hope',
#  'keep',
#  'Thank',
#  'tweet',
#  'girl',
#  'life',
#  'Hey',
#  'working',
#  'everyone',
#  'Do',
#  'Yeah',
#  'sucks',
#  'went',
#  'done',
#  'away',
#  'ever',
#  'A',
#  'wo',
#  'lot',
#  'phone',
#  'might',
#  'missed',
#  'bit',
#  'actually',
#  'glad',
#  'friend',
#  'guess',
#  'mean',
#  'give',
#  'song',
#  'live',
#  'sounds',
#  'stuff',
#  'maybe',
#  'saw',
#  'luck',
#  'year',
#  'old',
#  'gt',
#  'makes',
#  '$',
#  'school',
#  'also',
#  'welcome',
#  'coming',
#  'least',
#  'bed',
#  'Well',
#  'Twitter',
#  'Not',
#  'looking',
#  'anything',
#  'around',
#  'Sorry',
#  'someone',
#  'use',
#  'wanted',
#  'If',
#  'friends',
#  'looks',
#  'movie',
#  'left',
#  'read',
#  'many',
#  'Yes',
#  'call',
#  'since',
#  'lost',
#  'hard',
#  'tho',
#  'cute',
#  'aww',
#  'funny',
#  'another',
#  'talk',
#  'big',
#  'amazing',
#  'nothing',
#  'following',
#  '1',
#  'feeling',
#  'later',
#  'put',
#  'He',
#  'must',
#  'They',
#  'sick',
#  'trying',
#  'watching',
#  'n',
#  'two',
#  'start',
#  'play',
#  'U',
#  'ta',
#  'mine',
#  'Haha',
#  'hahaha',
#  'followfriday',
#  'either',
#  'house',
#  'check',
#  'far',
#  'Im',
#  'baby',
#  'okay',
#  'seen',
#  'music',
#  'real',
#  'followers',
#  'didnt',
#  'job',
#  'name',
#  'r',
#  'pic',
#  'may',
#  'wrong',
#  'everything',
#  'totally',
#  'yesterday',
#  'enough',
#  'Love',
#  'YOU',
#  'idea',
#  'late',
#  'summer',
#  'true',
#  'times',
#  'game',
#  'aplusk',
#  'hours',
#  'free',
#  'early',
#  'video',
#  'ha',
#  'send',
#  'found',
#  'hot',
#  'without',
#  'excited',
#  'tweets',
#  'end',
#  'sweet',
#  'leave',
#  'This',
#  'probably',
#  'Now',
#  'anymore',
#  'Hi',
#  'enjoy',
#  'using',
#  'damn',
#  'place',
#  'used',
#  'Me',
#  'fine',
#  'gone',
#  'xx',
#  'heard',
#  'win',
#  'stop',
#  'every',
#  'thinking',
#  'mom',
#  'Lol',
#  'cause',
#  'head',
#  'weather',
#  'wow',
#  'birthday',
#  'able',
#  'poor',
#  'party',
#  'making',
#  'years',
#  'buy',
#  'hi',
#  'forward',
#  'add',
#  'hehe',
#  'pay',
#  'remember',
#  'Happy',
#  'kind',
#  'told',
#  'world',
#  'link',
#  'jealous',
#  'ill',
#  'Why',
#  '5',
#  'omg',
#  'course',
#  'tired',
#  'till',
#  'Is',
#  'awww',
#  'ago',
#  'shit',
#  'Ca',
#  'meet',
#  'beautiful',
#  'Your',
#  '=',
#  'money',
#  'car',
#  'believe',
#  'rain',
#  'She',
#  'Get',
#  'stay',
#  'tried',
#  'waiting',
#  'eat',
#  'else',
#  'anyway',
#  'pics',
#  'almost',
#  'person',
#  'dude',
#  'post',
#  'yay',
#  'mind',
#  'busy',
#  'ready',
#  'picture',
#  'problem',
#  'Its',
#  'seems',
#  'called',
#  'lovely',
#  'hair',
#  'talking',
#  'kinda',
#  'weeks',
#  'came',
#  'fan',
#  'Did',
#  'quite',
#  'agree',
#  'face',
#  '100',
#  'reply',
#  'guy',
#  'lucky',
#  'news',
#  'iPhone',
#  'family',
#  'food',
#  'ask',
#  '/',
#  'blog',
#  'There',
#  'part',
#  'cuz',
#  'yea',
#  'happened',
#  'gets',
#  'crazy',
#  'care',
#  'site',
#  ']',
#  'heart',
#  'coffee',
#  'seeing',
#  'book',
#  'online',
#  'Will',
#  'email',
#  'wont',
#  'btw',
#  'kids',
#  'bring',
#  'w/',
#  'playing',
#  'says',
#  'forgot',
#  'OMG',
#  'finally',
#  'LOVE',
#  'definitely',
#  'whole',
#  'ones',
#  'Glad',
#  'missing',
#  'means',
#  'train',
#  'Maybe',
#  'started',
#  '10',
#  'room',
#  'lots',
#  'cold',
#  'sun',
#  'sound',
#  'SO',
#  'story',
#  'rest',
#  'Are',
#  'change',
#  'stupid',
#  'anyone',
#  'b',
#  'together',
#  'full',
#  'hour',
#  'ashleytisdale',
#  'goes',
#  'bored',
#  'Friday',
#  'happen',
#  'run',
#  'Nice',
#  'loved',
#  'andyclemmensen',
#  'Please',
#  'trip',
#  'list',
#  'sent',
#  'sometimes',
#  'works',
#  'Got',
#  'Great',
#  'took',
#  'AlexAllTimeLow',
#  'lunch',
#  'hello',
#  'ME',
#  'knew',
#  'IT',
#  'In',
#  'favorite',
#  'month',
#  'listen',
#  'reason',
#  '%',
#  'lmao',
#  'sooo',
#  'Aww',
#  'Let',
#  'chance',
#  'soo',
#  'hang',
#  'When',
#  'super',
#  'reading',
#  'words',
#  'wonderful',
#  'girls',
#  'hurt',
#  'All',
#  'cry',
#  'hit',
#  'DM',
#  'dad',
#  'word',
#  'suck',
#  'message',
#  'Alyssa_Milano',
#  'hopefully',
#  'ppl',
#  '6',
#  '*sigh*',
#  'couple',
#  'xxx',
#  'aw',
#  'watched',
#  'O',
#  'THE',
#  'understand',
#  'computer',
#  'write',
#  'ass',
#  'meant',
#  'taking',
#  'dog',
#  'NOT',
#  'saying',
#  'Morning',
#  'comes',
#  'hell',
#  'update',
#  'dear',
#  'hurts',
#  'move',
#  'pain',
#  'forget',
#  'Still',
#  'worth',
#  'Sounds',
#  'point',
#  'visit',
#  'alone',
#  'liked',
#  'boy',
#  'bout',
#  'Wish',
#  'D',
#  'stuck',
#  'needs',
#  'friday',
#  'close',
#  'worry',
#  'album',
#  'til',
#  'supposed',
#  'bet',
#  'half',
#  'Once',
#  'TO',
#  'drive',
#  'text',
#  'seem',
#  'listening',
#  'concert',
#  'Sunday',
#  'finished',
#  'drink',
#  'break',
#  'ah',
#  'page',
#  'Yay',
#  'less',
#  'God',
#  'season',
#  'side',
#  'congrats',
#  'top',
#  'dinner',
#  'At',
#  'smile',
#  'yep',
#  'seriously',
#  'class',
#  '[',
#  'boo',
#  'internet',
#  'crap',
#  'mad',
#  'open',
#  'minutes',
#  'interesting',
#  'instead',
#  'outside',
#  'god',
#  'catch',
#  'Wow',
#  'musicmonday',
#  'office',
#  'xD',
#  'vip',
#  'plan',
#  'turn',
#  'answer',
#  '8',
#  'Very',
#  'died',
#  'songs',
#  'months',
#  'gave',
#  'sister',
#  'indeed',
#  'leaving',
#  'hoping',
#  '+',
#  'set',
#  'weird',
#  'myweakness',
#  'easy',
#  'iremember',
#  'To',
#  'rock',
#  'earlier',
#  'whats',
#  'account',
#  'Monday',
#  'photo',
#  'ugh',
#  'Where',
#  'moment',
#  'town',
#  'tickets',
#  'unfortunately',
#  'different',
#  'Welcome',
#  'number',
#  'ive',
#  'boys',
#  'FF',
#  '*',
#  'hun',
#  'Was',
#  'looked',
#  'Enjoy',
#  'backstreetboys',
#  'Or',
#  'thx',
#  'wants',
#  'facebook',
#  'line',
#  'join',
#  '1st',
#  'fuck',
#  'bought',
#  'p',
#  'Can',
#  'perfect',
#  'exactly',
#  'hug',
#  'shows',
#  'laugh',
#  'babe',
#  'One',
#  'movies',
#  'chocolate',
#  'Day',
#  'chat',
#  'pick',
#  'See',
#  'Congrats',
#  'running',
#  'babygirlparis',
#  'fail',
#  'water',
#  'woke',
#  'Too',
#  '30SECONDSTOMARS',
#  'broke',
#  'tv',
#  'huh',
#  'cut',
#  'AND',
#  'Ah',
#  'support',
#  'NO',
#  'mate',
#  'MY',
#  'fair',
#  'second',
#  'worse',
#  'store',
#  'eating',
#  'fans',
#  'raining',
#  'Awww',
#  'shopping',
#  '»',
#  'For',
#  'version',
#  'Go',
#  'S',
#  'high',
#  'New',
#  'lady',
#  'fucking',
#  'worked',
#  'Really',
#  'dance',
#  'soooo',
#  'exam',
#  'doesnt',
#  'afternoon',
#  '7',
#  'special',
#  'short',
#  'fast',
#  'date',
#  'annoying',
#  'safe',
#  'comment',
#  'luv',
#  'past',
#  'website',
#  'via',
#  'beach',
#  'updates',
#  'nope',
#  'THAT',
#  'tour',
#  'hungry',
#  'asleep',
#  'cos',
#  'share',
#  'wonder',
#  'Saturday',
#  'walk',
#  'dead',
#  'eyes',
#  'lil',
#  'Hello',
#  'havent',
#  'team',
#  'pictures',
#  'kid',
#  'case',
#  'yo',
#  'cream',
#  'usually',
#  'Damn',
#  'wake',
#  'near',
#  'idk',
#  'meeting',
#  'black',
#  'ride',
#  'happens',
#  'tweeting',
#  'ice',
#  'met',
#  'question',
#  'slow',
#  'photos',
#  'longer',
#  'evening',
#  'needed',
#  'moving',
#  'shall',
#  'books',
#  'starting',
#  'rather',
#  'Awesome',
#  'June',
#  'brother',
#  'Poor',
#  'dream',
#  'fall',
#  'red',
#  'beer',
#  'da',
#  'sunny',
#  'IS',
#  'hand',
#  'boring',
#  'horrible',
#  'em',
#  'knows',
#  'sleeping',
#  'aint',
#  'learn',
#  'posted',
#  'sign',
#  'laptop',
#  'eh',
#  '20',
#  'whatever',
#  'Who',
#  'loves',
#  'XD',
#  'others',
#  'lame',
#  'tea',
#  'writing',
#  'hahah',
#  '30',
#  'goin',
#  'Aw',
#  'Cool',
#  'worst',
#  'small',
#  'silly',
#  'mention',
#  'alright',
#  'along',
#  'Like',
#  'sunday',
#  'Come',
#  'die',
#  'cat',
#  'shut',
#  'save',
#  'squarespace',
#  'US',
#  'dreams',
#  'inaperfectworld',
#  'etc',
#  'def',
#  'wedding',
#  'yup',
#  'appreciate',
#  'TV',
#  'finish',
#  'awake',
#  'UK',
#  'due',
#  'mum',
#  'c',
#  'upset',
#  'lately',
#  'proud',
#  'feels',
#  'enjoying',
#  'As',
#  'deal',
#  'alot',
#  'lets',
#  'three',
#  'sadly',
#  'asked',
#  'hold',
#  'self',
#  'info',
#  'exams',
#  'matter',
#  'youtube',
#  'fell',
#  'pass',
#  'apparently',
#  'plus',
#  'bradiewebbstack',
#  'On',
#  'Would',
#  'YAY',
#  'broken',
#  'crying',
#  'parents',
#  'huge',
#  'Then',
#  'wear',
#  'Birthday',
#  'Tell',
#  'Yep',
#  'Only',
#  'breakfast',
#  'nite',
#  'DO',
#  'white',
#  'camera',
#  'beat',
#  'scared',
#  'xoxo',
#  'study',
#  'Had',
#  'green',
#  'bday',
#  'vote',
#  'FollowFriday',
#  'kill',
#  'felt',
#  'plans',
#  'LA',
#  'wit',
#  'single',
#  'forever',
#  'body',
#  'Night',
#  'business',
#  'billyraycyrus',
#  'sharing',
#  'Of',
#  'type',
#  'sitting',
#  'profile',
#  'ahh',
#  'random',
#  'giving',
#  'especially',
#  'London',
#  'exciting',
#  'order',
#  'fix',
#  'shame',
#  'myspace',
#  'Follow',
#  'city',
#  'front',
#  'dunno',
#  'Also',
#  'eye',
#  'pool',
#  'son',
#  'sense',
#  'absolutely',
#  'July',
#  'monday',
#  'hmm',
#  'prob',
#  'gorgeous',
#  '~',
#  'serious',
#  'Keep',
#  'voice',
#  'behind',
#  'except',
#  'app',
#  'figure',
#  'sold',
#  'living',
#  'played',
#  'sexy',
#  'wine',
#  'taken',
#  'keeps',
#  'mood',
#  'coz',
#  'goodnight',
#  'film',
#  'touch',
#  'Ok',
#  'sweetie',
#  'band',
#  '|',
#  'bitch',
#  'club',
#  'fact',
#  'sis',
#  'BSB',
#  'enjoyed',
#  'awwww',
#  'lose',
#  'future',
#  'sort',
#  'blue',
#  'woman',
#  'Am',
#  '12',
#  '2nd',
#  'somewhere',
#  'invite',
#  '*hugs*',
#  'cake',
#  'bro',
#  'box',
#  'radio',
#  'kidding',
#  'iphone',
#  'air',
#  'minute',
#  'warm',
#  'power',
#  'country',
#  'test',
#  'flight',
#  'YES',
#  'OK',
#  'Chris',
#  'LMAO']

# %%
#Downloading wordnet
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Stemming
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

def stem_tokenize(text):
    stemm = SnowballStemmer("english")
    stemm = WordNetLemmatizer()
    return [stemm.lemmatize(token) for token in word_tokenize(text)]

def lemmatize_tokenize(text):
    lemmatizer = WordNetLemmatizer()
    return [lemmatizer.lemmatize(token) for token in word_tokenize(text)]

# %% [markdown]
# **PREPARING DATA**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#BUILDING PIPELINE
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.pipeline import Pipeline


class TextPreProc(BaseEstimator,TransformerMixin):
    def __init__(self, use_mention=False):
        self.use_mention = use_mention
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        
        if self.use_mention:
            X = X.str.replace(r"@[a-zA-Z0-9_]* ", " @tags ")
        else:
            X = X.str.replace(r"@[a-zA-Z0-9_]* ", "")
            
        
        X = X.str.replace("#", "")
        X = X.str.replace(r"[-\.\n]", "")
        
        X = X.str.replace(r"&\w+;", "")
       
        X = X.str.replace(r"https?://\S*", "")
        
        
        X = X.str.replace(r"(.)\1+", r"\1\1")
       
        X = X.str.replace(HAPPY_EMO, " happyemoticons ")
        X = X.str.replace(SAD_EMO, " sademoticons ")
        X = X.str.lower()
        return X

# %%
from sklearn.model_selection import train_test_split

sentiments = t_data['Sentiment']
tweets = t_data['SentimentText']

vectorizer = TfidfVectorizer(tokenizer=lemmatize_tokenize, ngram_range=(1,2))
pipeline = Pipeline([
    ('text_pre_processing', TextPreProc(use_mention=True)),
    ('vectorizer', vectorizer),
])

learn_data, test_data, sentiments_learning, sentiments_test = train_test_split(tweets, sentiments, test_size=0.3)
learning_data = pipeline.fit_transform(learn_data)

# %% [markdown]
# **MODEL SELECTION**

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB, MultinomialNB

lr = LogisticRegression()
bnb = BernoulliNB()
mnb = MultinomialNB()

models = {
    'logitic regression': lr,
    'bernoulliNB': bnb,
    'multinomialNB': mnb,
}

for model in models.keys():
    scores = cross_val_score(models[model], learning_data, sentiments_learning, scoring="f1", cv=10)
    print("===", model, "===")
    print("scores = ", scores)
    print("mean = ", scores.mean())
    print("variance = ", scores.var())
    models[model].fit(learning_data, sentiments_learning)
    print("score on the learning data (accuracy) = ", accuracy_score(models[model].predict(learning_data), sentiments_learning))
    print("")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# === logitic regression ===
# scores =  [0.81084412 0.80547149 0.80948369 0.81135952 0.813208   0.80894553
#  0.81109102 0.81177606 0.80726563 0.80947177]
# mean =  0.8098916834396446
# variance =  4.672112396520659e-06
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# score on the learning data (accuracy) =  0.8721568179220482
#
# === bernoulliNB ===
# scores =  [0.79271178 0.78466981 0.78981189 0.78306754 0.79227618 0.78727866
#  0.78638278 0.78706074 0.78500473 0.78513274]
# mean =  0.7873396867892899
# variance =  9.603953444507823e-06
# score on the learning data (accuracy) =  0.9051891644759401
#
# === multinomialNB ===
# scores =  [0.81161377 0.80396799 0.81122619 0.80830172 0.80764529 0.80655157
#  0.80798669 0.80341691 0.80044693 0.80634708]
# mean =  0.8067504139426701
# variance =  1.072109552799537e-05
# score on the learning data (accuracy) =  0.8986455594925135

# %% [markdown]
# **TUNING THE MODEL**

# %%
from sklearn.model_selection import GridSearchCV

grid_search_pipeline = Pipeline([
    ('text_pre_processing', TextPreProc()),
    ('vectorizer', TfidfVectorizer()),
    ('model', MultinomialNB()),
])

params = [
    {
        'text_pre_processing__use_mention': [True, False],
        'vectorizer__max_features': [1000, 2000, 5000, 10000, 20000, None],
        'vectorizer__ngram_range': [(1,1), (1,2)],
    },
]
grid_search = GridSearchCV(grid_search_pipeline, params, cv=5, scoring='f1')
grid_search.fit(learn_data, sentiments_learning)
print(grid_search.best_params_)
# Out:
# {'text_pre_processing__use_mention': True, 'vectorizer__max_features': None, 'vectorizer__ngram_range': (1, 2)}

# %% [markdown]
# **TESTING**

# %%
mnb.fit(learning_data, sentiments_learning)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
testing_data = pipeline.transform(test_data)
mnb.score(testing_data, sentiments_test)
# Out:
# 0.7585425209187585

# %% [markdown]
# **TESTING YOUR TWEETS**

# %%
model = MultinomialNB()
model.fit(learning_data, sentiments_learning)
tweet = pd.Series([input(),])
tweet = pipeline.transform(tweet)
proba = model.predict_proba(tweet)[0]
print("The probability that this tweet is sad is:", proba[0])
print("The probability that this tweet is happy is:", proba[1])
# Out:
# I GOT TICKET TO HOGWARTS!! YAAYYY
# The probability that this tweet is sad is: 0.43177397810406604
# The probability that this tweet is happy is: 0.5682260218959321
